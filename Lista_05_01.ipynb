# %% [markdown]
# <a href="https://colab.research.google.com/github/yurikomuta/ILP030/blob/master/Lista_05_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importando as bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Carregando os dados

# %%
df = pd.DataFrame({
    '% de Hidrocarboneto': [0.99, 1.02, 1.15, 1.29, 1.46, 1.36, 0.87, 1.23, 1.55, 1.40, 1.19, 1.15, 0.98, 1.01, 1.11, 1.20, 1.26, 1.32, 1.43, 0.95],
    'Pureza do O2': [90.01, 89.05, 91.43, 93.74, 96.73, 94.45, 87.59, 91.77, 99.42, 93.65, 93.54, 92.52, 90.56, 89.54, 89.85, 90.39, 93.25, 93.41, 94.98, 87.33]
})

# %% [markdown]
# # plotando o gráfico

# %%
plt.scatter(df['% de Hidrocarboneto'], df['Pureza do O2'])
plt.xlabel('% de Hidrocarboneto')
plt.ylabel('Pureza do O2')
plt.show()
